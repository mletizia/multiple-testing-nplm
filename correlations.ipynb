# %%
import os

from tests import *
from plot_utils import plot_correlations

# %% [markdown]
# # 1D

# %%
null_folder = "./test_statistics/univariate/NR200000_NB2000_NS0_M1000_lam1e-06/"
alt_folders = [
    "./test_statistics/univariate/NR200000_NB2000_NS7_loc4_std0.01_M1000_lam1e-06/",
    "./test_statistics/univariate/NR200000_NB2000_NS10_loc6.4_std0.16_M1000_lam1e-06/",
    "./test_statistics/univariate/NR200000_NB2000_NS13_loc4_std0.64_M1000_lam1e-06/",
    "./test_statistics/univariate/NR200000_NB2000_NS18_loc4_std0.16_M1000_lam1e-06/",
    "./test_statistics/univariate/NR200000_NB2000_NS90_loc1.6_std0.16_M1000_lam1e-06/",
]

output_folder = "./output_1D"

os.makedirs(output_folder, exist_ok=True)

# %%
tests = [0, 2, 3, 4, 7, 8]
flk_sigmas_all = [0.01, 0.1, 0.3, 0.7, 1.4, 2.3, 3.0, 4.5, 9.0]
flk_sigmas = [flk_sigmas_all[i] for i in tests]
labels_tests = [r'$\sigma=$ %s'%(str(flk_sigma)) for flk_sigma in flk_sigmas]

plot_correlations(null_folder, alt_folders, tests, labels_tests, output_folder)
# Out:
# ./test_statistics/univariate/NR200000_NB2000_NS0_M1000_lam1e-06/
# avg pair-wise correlation:  0.4513461826726336
# ./test_statistics/univariate/NR200000_NB2000_NS7_loc4_std0.01_M1000_lam1e-06/
# avg pair-wise correlation:  0.4384459341984311
# ./test_statistics/univariate/NR200000_NB2000_NS10_loc6.4_std0.16_M1000_lam1e-06/
# avg pair-wise correlation:  0.40714150422241363
# ./test_statistics/univariate/NR200000_NB2000_NS13_loc4_std0.64_M1000_lam1e-06/
# avg pair-wise correlation:  0.41851693607108753
# ./test_statistics/univariate/NR200000_NB2000_NS18_loc4_std0.16_M1000_lam1e-06/
# avg pair-wise correlation:  0.4200001861923749
# ./test_statistics/univariate/NR200000_NB2000_NS90_loc1.6_std0.16_M1000_lam1e-06/
# avg pair-wise correlation:  0.41397341233463214

# %% [markdown]
# # 5D

# %%
null_folder = "./test_statistics/dimuon/Ntoys2000_NR100000_NB20000_cut60_null/"
alt_folders = [
    "./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS60_Z180_cut60/",
    "./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS30_Z300_cut60/",
    "./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS8_Z600_cut60/",
    "./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS53_EFT5_cut60/"
]

output_folder = "./output_5D/"

os.makedirs(output_folder, exist_ok=True)

# %%
tests = [0,3,4,5,8,9]
flk_sigmas = [0.31, 1.19, 1.79, 2.49, 4.23, 8.0 ]
labels_tests = [r'$\sigma=$ %s'%(str(flk_sigma)) for flk_sigma in flk_sigmas]

plot_correlations(null_folder, alt_folders, tests, labels_tests, output_folder)
# Out:
# ./test_statistics/dimuon/Ntoys2000_NR100000_NB20000_cut60_null/
# avg pair-wise correlation:  0.34702881972673283
# ./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS60_Z180_cut60/
# avg pair-wise correlation:  0.3553358229110716
# ./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS30_Z300_cut60/
# avg pair-wise correlation:  0.34711031651734614
# ./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS8_Z600_cut60/
# avg pair-wise correlation:  0.33495813134101193
# ./test_statistics/dimuon/Ntoys1000_NR100000_NB20000_NS53_EFT5_cut60/
# avg pair-wise correlation:  0.3310549743998898

# %% [markdown]
# # 6D

# %%
null_folder = "./test_statistics/lhco/M853_lam1e-06_NB121339_NS0/"
alt_folders = [
    "./test_statistics/lhco/M853_lam1e-06_NB121339_NS333/"
]

output_folder = "./output_6D"

os.makedirs(output_folder, exist_ok=True)

# %%
tests = [0, 2, 3, 4, 6, 7, 8]
#flk_sigmas_all = [1.2, 1.7, 2.5, 3.2, 3.9, 4.6, 5.1, 6.1, 12.2]
#flk_sigmas = [flk_sigmas_all[i] for i in tests]
flk_sigmas = [1.2, 2.5, 3.2, 3.9, 5.1, 6.1, 12.2]
labels_tests = [r'$\sigma=$ %s'%(str(flk_sigma)) for flk_sigma in flk_sigmas]

plot_correlations(null_folder, alt_folders, tests, labels_tests, output_folder)
# Out:
# ./test_statistics/lhco/M853_lam1e-06_NB121339_NS0/
# avg pair-wise correlation:  0.5917969264593852
# ./test_statistics/lhco/M853_lam1e-06_NB121339_NS333/
# avg pair-wise correlation:  0.5915947316831736
